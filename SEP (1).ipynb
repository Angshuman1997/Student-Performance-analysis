# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
all_pass=df[(df['math score']>=40) & (df['reading score']>=40) & (df['writing score']>=40)] #949 students
all_fail=df[(df['math score']<40) & (df['reading score']<40) & (df['writing score']<40)]# 18 students
all_p1=df[(df['math score']>=40) & (df['reading score']>=40) & (df['writing score']<40)]#3 students
all_p2=df[(df['math score']>=40) & (df['reading score']<40) & (df['writing score']>=40)]#1 student
all_p3=df[(df['math score']<40) & (df['reading score']>=40) & (df['writing score']>=40)]#18 students
all_p4=df[(df['math score']<40) & (df['reading score']<40) & (df['writing score']>=40)]#0 student
all_p5=df[(df['math score']<40) & (df['reading score']>=40) & (df['writing score']<40)]#4 students
all_p6=df[(df['math score']>=40) & (df['reading score']<40) & (df['writing score']<40)]#7 students

# %%
len(all_pass[all_pass['gender']=='male'])
# Out:
# 462

# %%
data = {'Feature':['Total Students','Total pass', 'Total fail', 'Partial fail/pass'], 'Age':[len(df),len(all_pass),len(all_fail),len(df)-len(all_pass)-len(all_fail)]} 
df1 = pd.DataFrame(data)

# %%
labels = 'Total pass', 'Total fail', 'Partial fail/pass'
sizes = [len(all_pass),len(all_fail),len(df)-len(all_pass)-len(all_fail)]
explode = (0,0.5,0)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=False, startangle=360)
ax1.axis('equal')
plt.show()
df1
# Out:
#              Feature   Age
# 0     Total Students  1000
# 1         Total pass   949
# 2         Total fail    18
# 3  Partial fail/pass    33

# %%
barWidth = 0.15
# set height of bar
bars1 = [len(df[(df['race/ethnicity']=="group A") & (df['parental level of education']=="master's degree")]), len(df[(df['race/ethnicity']=="group B") & (df['parental level of education']=="master's degree")]),len(df[(df['race/ethnicity']=="group C") & (df['parental level of education']=="master's degree")]),len(df[(df['race/ethnicity']=="group D") & (df['parental level of education']=="master's degree")]),len(df[(df['race/ethnicity']=="group E") & (df['parental level of education']=="master's degree")])]
bars2 = [len(df[(df['race/ethnicity']=="group A") & (df['parental level of education']=="bachelor's degree")]),len(df[(df['race/ethnicity']=="group B") & (df['parental level of education']=="bachelor's degree")]),len(df[(df['race/ethnicity']=="group C") & (df['parental level of education']=="bachelor's degree")]),len(df[(df['race/ethnicity']=="group D") & (df['parental level of education']=="bachelor's degree")]),len(df[(df['race/ethnicity']=="group E") & (df['parental level of education']=="bachelor's degree")])]
bars3 = [len(df[(df['race/ethnicity']=="group A") & (df['parental level of education']=="associate's degree")]),len(df[(df['race/ethnicity']=="group B") & (df['parental level of education']=="associate's degree")]),len(df[(df['race/ethnicity']=="group C") & (df['parental level of education']=="associate's degree")]),len(df[(df['race/ethnicity']=="group D") & (df['parental level of education']=="associate's degree")]),len(df[(df['race/ethnicity']=="group E") & (df['parental level of education']=="associate's degree")])]
bars4 = [len(df[(df['race/ethnicity']=="group A") & (df['parental level of education']=="some college")]),len(df[(df['race/ethnicity']=="group B") & (df['parental level of education']=="some college")]),len(df[(df['race/ethnicity']=="group C") & (df['parental level of education']=="some college")]),len(df[(df['race/ethnicity']=="group D") & (df['parental level of education']=="some college")]),len(df[(df['race/ethnicity']=="group E") & (df['parental level of education']=="some college")])]
bars5 = [len(df[(df['race/ethnicity']=="group A") & (df['parental level of education']=="high school")]),len(df[(df['race/ethnicity']=="group B") & (df['parental level of education']=="high school")]),len(df[(df['race/ethnicity']=="group C") & (df['parental level of education']=="high school")]),len(df[(df['race/ethnicity']=="group D") & (df['parental level of education']=="high school")]),len(df[(df['race/ethnicity']=="group E") & (df['parental level of education']=="high school")])]
bars6 = [len(df[(df['race/ethnicity']=="group A") & (df['parental level of education']=="some high school")]),len(df[(df['race/ethnicity']=="group B") & (df['parental level of education']=="some high school")]),len(df[(df['race/ethnicity']=="group C") & (df['parental level of education']=="some high school")]),len(df[(df['race/ethnicity']=="group D") & (df['parental level of education']=="some high school")]),len(df[(df['race/ethnicity']=="group E") & (df['parental level of education']=="some high school")])]
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
r5 = [x + barWidth for x in r4]
r6 = [x + barWidth for x in r5] 
# Make the plot
plt.bar(r1, bars1, color='red', width=barWidth, edgecolor='black', label='masters degree')
plt.bar(r2, bars2, color='blue', width=barWidth, edgecolor='black', label='bachelors degree')
plt.bar(r3, bars3, color='green', width=barWidth, edgecolor='black', label='associates degree')
plt.bar(r4, bars4, color='yellow', width=barWidth, edgecolor='black', label='some college')
plt.bar(r5, bars5, color='orange', width=barWidth, edgecolor='black', label='high school')
plt.bar(r6, bars6, color='pink', width=barWidth, edgecolor='black', label='some high school')
  
# Add xticks on the middle of the group bars
plt.xlabel('Parental Education Statistics Group wise', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E'])
 
# Create legend & Show graphic
plt.legend()
plt.show()

# %%
labels = 'Male Pass', 'Female Pass','Male Fail', 'Female Fail','Partial Male Pass/Fail', 'Partial Female Pass/Fail'
sizes = [len(all_pass[all_pass['gender']=='male']),len(all_pass[all_pass['gender']=='female']),len(all_fail[all_fail['gender']=='male']),len(all_fail[all_fail['gender']=='female']),len(df[df['gender']=='male'])-len(all_pass[all_pass['gender']=='male'])-len(all_fail[all_fail['gender']=='male']),len(df[df['gender']=='female'])-len(all_pass[all_pass['gender']=='female'])-len(all_fail[all_fail['gender']=='female'])]
explode = (0,0.1,0.2,0.1,0.2,0.1)
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=False, startangle=360)
ax1.axis('equal')
plt.show()

# %%
data2 = {'Male Pass':len(all_pass[all_pass['gender']=='male']), 'Female Pass':len(all_pass[all_pass['gender']=='female']), 'Male Fail':len(all_fail[all_fail['gender']=='male']),'Female Fail':len(all_fail[all_fail['gender']=='female']),'Partial Male Pass/Fail':len(df[df['gender']=='male'])-len(all_pass[all_pass['gender']=='male'])-len(all_fail[all_fail['gender']=='male']),'Partial Female Pass/Fail':len(df[df['gender']=='female'])-len(all_pass[all_pass['gender']=='female'])-len(all_fail[all_fail['gender']=='female'])} 
courses = list(data2.keys()) 
values = list(data2.values()) 
   
fig = plt.figure(figsize = (20, 5)) 
  
# creating the bar plot 
plt.bar(courses, values, color ='blue',  
        width = 0.4) 
  
plt.xlabel("Gender wise marks statistics") 
plt.ylabel("Marks Tally") 
#plt.title("Students enrolled in different courses") 
plt.show()

# %%
d1=df
d1['Total']=df['math score']+df['reading score']+df['writing score']
d1['Percentage']=((df['math score']+df['reading score']+df['writing score'])/300)*100

# %%
gkk = d1.groupby(['race/ethnicity', 'parental level of education','gender'])

# %%
gkk.max()
# Out:
#                                                           lunch  \
# race/ethnicity parental level of education gender
# group A        associate's degree          female      standard
#                                            male        standard
#                bachelor's degree           female      standard
#                                            male        standard
#                high school                 female      standard
#                                            male        standard
#                master's degree             female      standard
#                                            male    free/reduced
#                some college                female      standard
#                                            male        standard
#                some high school            female      standard
#                                            male        standard
# group B        associate's degree          female      standard
# ...

# %%
gkk1 = d1.groupby(['race/ethnicity', 'test preparation course','gender'])

# %%
gkk1.max()
# Out:
#                                               parental level of education  \
# race/ethnicity test preparation course gender
# group A        completed               female            some high school
#                                        male              some high school
#                none                    female            some high school
#                                        male              some high school
# group B        completed               female            some high school
#                                        male              some high school
#                none                    female            some high school
#                                        male              some high school
# group C        completed               female            some high school
#                                        male              some high school
#                none                    female            some high school
# ...

# %%
#d1[(d1['race/ethnicity']=='group A') & (d1['Percentage']>=90)]

# %%
#d1[(d1['race/ethnicity']=='group B') & (d1['Percentage']>=90)]

# %%
#d1[(d1['race/ethnicity']=='group C') & (d1['Percentage']>=90)]

# %%
#d1[(d1['race/ethnicity']=='group D') & (d1['Percentage']>=90)]

# %%
#d1[(d1['race/ethnicity']=='group E') & (d1['Percentage']>=90)]

# %%
# Make fake dataset
height = [len(d1[d1['Percentage']>90]),len(d1[d1['Percentage']>80]), 5, 18, 45,10,33]
ranges = ('91 - 100', '81 - 90', '71 - 80', '61 - 70', '51 - 60','40 - 50','Below 40')
y_pos = np.arange(len(ranges))
 
# Create horizontal bars
plt.barh(y_pos, height)
 
# Create names on the y-axis
plt.yticks(y_pos, ranges)
 
# Show graphic
plt.show()
